# %% [markdown]
# ## PROJETO FINAL DE DISCIPLINA
#
# PONTIFÍCIA UNIVERSIDADE CATÓLICA DE SÃO PAULO
#
# FACULDADE DE ESTUDOS INTERDISCIPLINARES
#
# BACHARELADO EM CIÊNCIA DE DADOS E INTELIGÊNCIA ARTIFICIAL
#
# DISCIPLINA CONSULTORIA ESPECIALIZADA DE APOIO AO PROJETO INTEGRADO: ALGORÍTMOS E PROGRAMAÇÃO
#
# PROF. DR. JEFFERSON DE OLIVEIRA SILVA

# %% [markdown]
# ## INTEGRANTES:
# * Murillo Carvalho Pires Martins
# * Gabriel Rodrigues
# * Gabriel Hisaichi Machado Tanaka Arai
# * João Vitor Ribeiro Costard
# * José Vitor Santos Dias

# %% [markdown]
# ## QUESTÃO DIRIGIDA
#
# * Como uma simulação da coleta seletiva pode contribuir de maneira eficaz com o planejamento municipal?

# %% [markdown]
# ## DESCRIÇÃO DO PROJETO
#
#
# O lixo na cidade de São Paulo se torna a cada ano um problema maior causando a contaminaçao do solo, enchentes, deslizamentos, mau cheiro, poluiçao etc..
#
# O setor de recilcagem movimenta em média 12 bilhões de reais por ano mas o pais perde cerca de 8 bilhões por ano pelo fato de nao reciclar certos materiais.
#
# Com esse trabalho queremos achar uma maneira mais eficaz para se realizar a coleta seletiva nas ruas usando como base o jogo Pac-Man e algoritmos de busca.

# %% [markdown]
# REQ 1 - Customização do programa
# - O programa foi customizado nas seguintes funções:
# - agente_com_um_destino(cores das células de origem e destino)
# - desenhar_se(representaçao de um caminhao de lixo)
# - desenhar_celula(mudança de cor da célula)
# - criar_tela(mudança da cor do background)
# - ler_fixa(matriz fixa para representar um pequeno bairro)

# %%
##REQ 4 - Um unico agente percorrendo todo o labirinto##

def um_agente_percorre_tudo():
    dimensao_da_matriz = 20
    lab = Labirinto(dimensao_da_matriz)
    id = 0
    agente = lab.add_pacman(id)

    intervalo_entre_frames = 0.1

    chegou_ao_fim = False
    while (not chegou_ao_fim):
        chegou_ao_fim = agente.percorrer()
        update()
        sleep(intervalo_entre_frames)

# %%
##REQ 5 - N Agentes percorrendo todo o labirinto##

def n_agentes_percorrem_tudo():
    dimensao_da_matriz = 20
    lab = Labirinto(dimensao_da_matriz)
    id = 0
    n_agentes = 4
    intervalo_entre_frames = 0.1
    chegou_ao_fim = False
    agentes = lab.agentes

    for id in range(0, n_agentes):
        f = lab.add_pacman(id)
        
    while (not chegou_ao_fim):
        for id in agentes.keys():
            chegou_ao_fim = agentes[id].percorrer()
        update()
        sleep(intervalo_entre_frames)

# %%
##REQ 7 - Um agente usando o algortimo A Estrela##

def agente_com_um_destino():
    dimensao_da_matriz = 20
    lab = Labirinto(dimensao_da_matriz)
    id = 0
    agente = lab.add_pacman(id)

    origem = agente._posicao
    destino = lab.cel_aleatoria()

    lab.desenhar_celula(origem, 'red')
    lab.desenhar_celula(destino, 'green')

    intervalo_entre_frames = 0.1

    chegou_ao_destino = False
    while (not chegou_ao_destino):
        chegou_ao_destino = agente.ir_a(destino)
        update()
        sleep(intervalo_entre_frames)

# %% [markdown]
# REQ 10 - Trabalho entrege em caderno Jupyter

# %% [markdown]
# Limitações do programa:
# - Não se pode destinguir o tipo de lixo coletado por cada caminhão
# - Não se pode criar "bairros" aleatorios com  uma estrutura cooerente
#
# Futuros planos:
# - Analisar quanto tempo uma quantidade N de caminhões demora para coletar o lixo de todas as casas e achar o numero de caminhões onde a média em comparação as outras é a mais vantajosa

# %% [markdown]
# # Conlusão
# Com esse trabalho podemos analisar e melhorar a coleta  seletiva com base nos dados coletados por simulações a fim de encontrar o melhor meio de coletar o lixo de todo o bairro.
# Com a melhora da coleta seletiva podemos diminuir o desperdício, diminuir os gastos e até gerar empregos com por meio da reciclagem
